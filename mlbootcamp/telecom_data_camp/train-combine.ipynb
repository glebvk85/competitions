# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
# %matplotlib inline

# %%
from keras.callbacks import Callback
from matplotlib import pyplot as plt
from IPython.display import clear_output
class PlotLearning(Callback):
    def on_train_begin(self, logs={}):
        self.i = 0
        self.x = []
        self.losses = []
        self.val_losses = []
        self.acc = []
        self.val_acc = []
        self.fig = plt.figure()
        
        self.logs = []

    def on_epoch_end(self, epoch, logs={}):
        
        self.logs.append(logs)
        self.x.append(self.i)
        self.losses.append(logs.get('loss'))
        self.val_losses.append(logs.get('val_loss'))
        self.acc.append(logs.get('auc'))
        self.val_acc.append(logs.get('val_auc'))
        self.i += 1
        f, (ax1, ax2) = plt.subplots(1, 2, sharex=True,figsize=(15,10))
        
        clear_output(wait=True)
        
        ax1.set_yscale('log')
        ax1.plot(self.x, self.losses, label="loss")
        ax1.plot(self.x, self.val_losses, label="validation_loss")
        ax1.legend()
        
        ax2.plot(self.x, self.acc, label="accuracy")
        ax2.plot(self.x, self.val_acc, label="validation accuracy")
        ax2.legend()
        
        plt.show();
        
plot = PlotLearning()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import telepot
def send_notify(text):
    with open('../../_access_keys/telegram_token.txt', 'r') as content_file:
        token = content_file.read()
    with open('../../_access_keys/user.txt', 'r') as content_file:
        user = content_file.read()
    try:
        TelegramBot = telepot.Bot(token)
        TelegramBot.sendMessage(int(user), text)
    except:
        pass

# %%
TRAIN = True

# %%
path = 'c:/data/mlbootcamp/dataset/'
path_train = path + 'train/'
path_test = path + 'test/'
path_features = 'features/'
if TRAIN:
    pathfiles = path_train
    path_subs_bs_consumption = 'subs_bs_consumption_train.csv'
    path_subs_bs_data_session = 'subs_bs_data_session_train.csv'
    path_subs_bs_voice_session = 'subs_bs_voice_session_train.csv'
    path_subs_features = 'subs_features_train.csv'
    path_subs_csi = 'subs_csi_train.csv'
    path_new_features = 'features.csv'
else:
    pathfiles = path_test
    path_subs_bs_consumption = 'subs_bs_consumption_test.csv'
    path_subs_bs_data_session = 'subs_bs_data_session_test.csv'
    path_subs_bs_voice_session = 'subs_bs_voice_session_test.csv'
    path_subs_features = 'subs_features_test.csv'
    path_subs_csi = 'subs_csi_test.csv'
    path_new_features = 'features.csv'

# %%
subs_csi = pd.read_csv(pathfiles + path_subs_csi, sep=';', decimal=',')

# %%
subs_csi.head(1)
# Out:
#    SK_ID  CSI CONTACT_DATE
# 0      2    0        04.05

# %%
subs_csi.shape
# Out:
# (4222, 3)

# %%
subs_bs_consumption = pd.read_csv(pathfiles + path_subs_bs_consumption, sep=';', decimal=',')

# %%
subs_bs_consumption['month'] = subs_bs_consumption['MON'].apply(lambda x:int(str(x).split('.')[1]))

# %%
subs_bs_consumption.head(1)
# Out:
#    SK_ID  CELL_LAC_ID    MON  SUM_MINUTES  SUM_DATA_MB  SUM_DATA_MIN  month
# 0   1827       240277  01.03          0.0     0.000002      0.000234      3

# %%
subs_bs_consumption.shape
# Out:
# (1092544, 7)

# %%
subs_bs_data_session = pd.read_csv(pathfiles + path_subs_bs_data_session, sep=';', decimal=',')

# %%
subs_bs_data_session.head(1)
# Out:
#    SK_ID  CELL_LAC_ID  DATA_VOL_MB      START_TIME
# 0   3853        61951     0.000004  04.04 05:00:00

# %%
subs_bs_data_session.shape
# Out:
# (3473203, 4)

# %%
subs_features = pd.read_csv(pathfiles + path_subs_features, sep=';', decimal=',')

# %%
subs_features.head(1)
# Out:
#   SNAP_DATE  COM_CAT#1  SK_ID  COM_CAT#2  COM_CAT#3  BASE_TYPE  ACT  \
# 0  01.08.01          4   3339         80          5          2    1
#
#    ARPU_GROUP  COM_CAT#7  COM_CAT#8     ...      COM_CAT#25  COM_CAT#26  \
# 0        12.0          1     1489.0     ...               1           1
#
#    COM_CAT#27  COM_CAT#28  COM_CAT#29  COM_CAT#30  COM_CAT#31  COM_CAT#32  \
# 0    0.031696    0.076724    0.040279      0.0133    0.083382    0.027579
#
#    COM_CAT#33  COM_CAT#34
# 0    0.103896         2.0
#
# [1 rows x 36 columns]

# %%
subs_features.shape
# Out:
# (47411, 36)

# %%
subs_features['SNAP_DATE'] = subs_features['SNAP_DATE'].apply(lambda x:datetime.strptime(x, '%d.%m.%y'))

# %%
cats = subs_features['COM_CAT#24'].unique()
subs_features['COM_CAT#242'] = pd.Categorical(subs_features['COM_CAT#24'], categories=cats)
subs_features['COM_CAT#242'] = subs_features['COM_CAT#242'].cat.codes

# %%
subs_features['COM_CAT#34'].fillna(0, inplace=True)
subs_features['COM_CAT#8'].fillna(0, inplace=True)
subs_features['DEVICE_TYPE_ID'].fillna(0, inplace=True)
subs_features['ARPU_GROUP'].fillna(0, inplace=True)
subs_features['INTERNET_TYPE_ID'].fillna(0, inplace=True)

# %%
subs_features.dropna().shape
# Out:
# (47411, 37)

# %%
subs_features['month'] = subs_features['SNAP_DATE'].apply(lambda x:x.month)
subs_features['year'] = subs_features['SNAP_DATE'].apply(lambda x:x.year)

# %%
columns = ['COM_CAT#1', 'COM_CAT#2', 'COM_CAT#3', 'BASE_TYPE', 'ACT', 'ARPU_GROUP', 'COM_CAT#7', 'COM_CAT#8',
          'DEVICE_TYPE_ID', 'INTERNET_TYPE_ID', 'REVENUE', 'ITC', 'VAS', 'RENT_CHANNEL', 'ROAM',
          'COST', 'COM_CAT#242']
for i in range(18):
    if i + 17 == 24:
        continue
    columns.append('COM_CAT#{}'.format(i+17))

# %%
subs_features.head()
# Out:
#    SNAP_DATE  COM_CAT#1  SK_ID  COM_CAT#2  COM_CAT#3  BASE_TYPE  ACT  \
# 0 2001-08-01          4   3339         80          5          2    1
# 1 2001-08-01          4    238         75          5          2    1
# 2 2001-08-01          4   4669         43          5          2    1
# 3 2001-08-01          4   2555         54          5          2    1
# 4 2001-08-01          4   2291         38          5          2    1
#
#    ARPU_GROUP  COM_CAT#7  COM_CAT#8  ...   COM_CAT#28  COM_CAT#29  COM_CAT#30  \
# 0        12.0          1     1489.0  ...     0.076724    0.040279      0.0133
# 1         7.0          1      945.0  ...     0.012981    0.000000      0.0000
# 2         3.0          3     1033.0  ...     0.000000    0.000000      0.0000
# 3        12.0          1      512.0  ...     0.039486    0.000829      0.0000
# 4         7.0          1     1268.0  ...     0.007385    0.003884      0.0000
#
#    COM_CAT#31  COM_CAT#32  COM_CAT#33  COM_CAT#34  COM_CAT#242  month  year
# 0    0.083382    0.027579    0.103896         2.0            0      8  2001
# 1    0.048930    0.027579    0.103896         3.0            0      8  2001
# 2    0.009397    0.027579    0.103896         3.0            0      8  2001
# 3    0.196676    0.027579    0.103896         1.0            0      8  2001
# 4    0.047297    0.027579    0.103896         6.0            0      8  2001
#
# [5 rows x 39 columns]

# %%
subs_features.describe()
# Out:
#           COM_CAT#1         SK_ID     COM_CAT#2     COM_CAT#3     BASE_TYPE  \
# count  47411.000000  47411.000000  47411.000000  47411.000000  47411.000000
# mean       4.538019   2346.231107     41.213642      5.267280      1.938706
# std        2.175724   1365.543733     22.381202      2.757143      0.239871
# min        1.000000      2.000000      1.000000      1.000000      1.000000
# 25%        3.000000   1160.000000     25.000000      5.000000      2.000000
# 50%        4.000000   2345.000000     38.000000      5.000000      2.000000
# 75%        6.000000   3543.000000     60.000000      5.000000      2.000000
# max        8.000000   4702.000000     83.000000     17.000000      2.000000
#
#                 ACT    ARPU_GROUP     COM_CAT#7     COM_CAT#8  DEVICE_TYPE_ID  \
# count  47411.000000  47411.000000  47411.000000  47411.000000    47411.000000
# mean       0.990909      7.669402      2.378119    863.775727        4.609015
# std        0.094912      3.182796      1.587738    517.414836        0.910221
# min        0.000000      0.000000      1.000000      0.000000        0.000000
# 25%        1.000000      5.000000      1.000000    387.000000        5.000000
# 50%        1.000000      8.000000      2.000000    915.000000        5.000000
# 75%        1.000000     10.000000      3.000000   1318.000000        5.000000
# max        1.000000     12.000000      9.000000   1702.000000        8.000000
#
#            ...         COM_CAT#28    COM_CAT#29    COM_CAT#30    COM_CAT#31  \
# count      ...       47411.000000  47411.000000  47411.000000  47411.000000
# mean       ...           0.018507      0.004788      0.005083      0.046062
# std        ...           0.031138      0.017611      0.021956      0.051001
# min        ...           0.000000      0.000000      0.000000      0.000000
# 25%        ...           0.001073      0.000000      0.000000      0.011571
# 50%        ...           0.007226      0.000120      0.000000      0.031394
# 75%        ...           0.022745      0.003028      0.000383      0.063415
# max        ...           0.645294      1.000000      1.000000      1.000000
#
#          COM_CAT#32    COM_CAT#33    COM_CAT#34   COM_CAT#242         month  \
# count  47411.000000  47411.000000  47411.000000  47411.000000  47411.000000
# mean       0.028243      0.104881      5.349391      0.000591      6.439265
# std        0.009148      0.007879      3.634229      0.054338      3.467740
# min        0.000000      0.000000      0.000000      0.000000      1.000000
# 25%        0.027579      0.103896      2.000000      0.000000      3.000000
# 50%        0.027579      0.103896      3.000000      0.000000      6.000000
# 75%        0.027579      0.103896      9.000000      0.000000      9.000000
# max        0.560674      0.377696     10.000000      7.000000     12.000000
#
#                year
# count  47411.000000
# mean    2001.432853
# std        0.495476
# min     2001.000000
# 25%     2001.000000
# 50%     2001.000000
# 75%     2002.000000
# max     2002.000000
#
# [8 rows x 37 columns]

# %%
if TRAIN:
    factors = {}
for c in columns:
    #emean =  np.mean(subs_features[c])
    if TRAIN:
        emin = np.min(subs_features[c])
    else:
        emin = factors[c][0]
    #subs_features[c] -= emean
    subs_features[c] -= emin
    if TRAIN:
        emax = np.max(subs_features[c])
    else:
        emax = factors[c][1]
    subs_features[c] /= emax
    if TRAIN:
        factors[c] = (emin, emax)

# %%
subs_features.describe()
# Out:
#           COM_CAT#1         SK_ID     COM_CAT#2     COM_CAT#3     BASE_TYPE  \
# count  47411.000000  47411.000000  47411.000000  47411.000000  47411.000000
# mean       0.505431   2346.231107      0.490410      0.266705      0.938706
# std        0.310818   1365.543733      0.272941      0.172321      0.239871
# min        0.000000      2.000000      0.000000      0.000000      0.000000
# 25%        0.285714   1160.000000      0.292683      0.250000      1.000000
# 50%        0.428571   2345.000000      0.451220      0.250000      1.000000
# 75%        0.714286   3543.000000      0.719512      0.250000      1.000000
# max        1.000000   4702.000000      1.000000      1.000000      1.000000
#
#                 ACT    ARPU_GROUP     COM_CAT#7     COM_CAT#8  DEVICE_TYPE_ID  \
# count  47411.000000  47411.000000  47411.000000  47411.000000    47411.000000
# mean       0.990909      0.639117      0.172265      0.507506        0.576127
# std        0.094912      0.265233      0.198467      0.304004        0.113778
# min        0.000000      0.000000      0.000000      0.000000        0.000000
# 25%        1.000000      0.416667      0.000000      0.227380        0.625000
# 50%        1.000000      0.666667      0.125000      0.537603        0.625000
# 75%        1.000000      0.833333      0.250000      0.774383        0.625000
# max        1.000000      1.000000      1.000000      1.000000        1.000000
#
#            ...         COM_CAT#28    COM_CAT#29    COM_CAT#30    COM_CAT#31  \
# count      ...       47411.000000  47411.000000  47411.000000  47411.000000
# mean       ...           0.028680      0.004788      0.005083      0.046062
# std        ...           0.048254      0.017611      0.021956      0.051001
# min        ...           0.000000      0.000000      0.000000      0.000000
# 25%        ...           0.001663      0.000000      0.000000      0.011571
# 50%        ...           0.011198      0.000120      0.000000      0.031394
# 75%        ...           0.035247      0.003028      0.000383      0.063415
# max        ...           1.000000      1.000000      1.000000      1.000000
#
#          COM_CAT#32    COM_CAT#33    COM_CAT#34   COM_CAT#242         month  \
# count  47411.000000  47411.000000  47411.000000  47411.000000  47411.000000
# mean       0.050374      0.277687      0.534939      0.000084      6.439265
# std        0.016316      0.020860      0.363423      0.007763      3.467740
# min        0.000000      0.000000      0.000000      0.000000      1.000000
# 25%        0.049189      0.275078      0.200000      0.000000      3.000000
# 50%        0.049189      0.275078      0.300000      0.000000      6.000000
# 75%        0.049189      0.275078      0.900000      0.000000      9.000000
# max        1.000000      1.000000      1.000000      1.000000     12.000000
#
#                year
# count  47411.000000
# mean    2001.432853
# std        0.495476
# min     2001.000000
# 25%     2001.000000
# 50%     2001.000000
# 75%     2002.000000
# max     2002.000000
#
# [8 rows x 37 columns]

# %%
subs_features[columns].describe()
# Out:
#           COM_CAT#1     COM_CAT#2     COM_CAT#3     BASE_TYPE           ACT  \
# count  47411.000000  47411.000000  47411.000000  47411.000000  47411.000000
# mean       0.505431      0.490410      0.266705      0.938706      0.990909
# std        0.310818      0.272941      0.172321      0.239871      0.094912
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.285714      0.292683      0.250000      1.000000      1.000000
# 50%        0.428571      0.451220      0.250000      1.000000      1.000000
# 75%        0.714286      0.719512      0.250000      1.000000      1.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#          ARPU_GROUP     COM_CAT#7     COM_CAT#8  DEVICE_TYPE_ID  \
# count  47411.000000  47411.000000  47411.000000    47411.000000
# mean       0.639117      0.172265      0.507506        0.576127
# std        0.265233      0.198467      0.304004        0.113778
# min        0.000000      0.000000      0.000000        0.000000
# 25%        0.416667      0.000000      0.227380        0.625000
# 50%        0.666667      0.125000      0.537603        0.625000
# 75%        0.833333      0.250000      0.774383        0.625000
# max        1.000000      1.000000      1.000000        1.000000
#
#        INTERNET_TYPE_ID      ...         COM_CAT#25    COM_CAT#26  \
# count      47411.000000      ...       47411.000000  47411.000000
# mean           0.632617      ...           0.999852      0.988420
# std            0.241901      ...           0.012150      0.106985
# min            0.000000      ...           0.000000      0.000000
# 25%            0.333333      ...           1.000000      1.000000
# 50%            0.666667      ...           1.000000      1.000000
# 75%            0.666667      ...           1.000000      1.000000
# max            1.000000      ...           1.000000      1.000000
#
#          COM_CAT#27    COM_CAT#28    COM_CAT#29    COM_CAT#30    COM_CAT#31  \
# count  47411.000000  47411.000000  47411.000000  47411.000000  47411.000000
# mean       0.017048      0.028680      0.004788      0.005083      0.046062
# std        0.025277      0.048254      0.017611      0.021956      0.051001
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.002169      0.001663      0.000000      0.000000      0.011571
# 50%        0.008714      0.011198      0.000120      0.000000      0.031394
# 75%        0.022257      0.035247      0.003028      0.000383      0.063415
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#          COM_CAT#32    COM_CAT#33    COM_CAT#34
# count  47411.000000  47411.000000  47411.000000
# mean       0.050374      0.277687      0.534939
# std        0.016316      0.020860      0.363423
# min        0.000000      0.000000      0.000000
# 25%        0.049189      0.275078      0.200000
# 50%        0.049189      0.275078      0.300000
# 75%        0.049189      0.275078      0.900000
# max        1.000000      1.000000      1.000000
#
# [8 rows x 34 columns]

# %%
def get_subs_features(year, month, fix_month, day, sk_id):
    data = subs_features[(subs_features['year'] == year) & (subs_features['month'] == month) & (subs_features['SK_ID'] == sk_id)]
    columns = ['COM_CAT#1', 'COM_CAT#2', 'COM_CAT#3', 'BASE_TYPE', 'ACT', 'ARPU_GROUP', 'COM_CAT#7', 'COM_CAT#8',
              'DEVICE_TYPE_ID', 'INTERNET_TYPE_ID', 'REVENUE', 'ITC', 'VAS', 'RENT_CHANNEL', 'ROAM',
              'COST', 'COM_CAT#242']
    for i in range(18):
        if i + 17 == 24:
            if data.shape[0] == 1:
                d = data[['COM_CAT#24']].values[0].tolist()[0]
                dt = str(d).split('.')
                c_month = int(dt[1])
                c_day = int(dt[0])
                delta = (datetime(2002, fix_month, day) - datetime(2001 if d == '31.12' else 2002, c_month, c_day)).days
            continue
        columns.append('COM_CAT#{}'.format(i+17))
    if data.shape[0] == 1:
        return columns, data[columns].values[0].tolist()
    else:
        return columns, np.zeros(len(columns))

# %%
# for dnn
table = []
if TRAIN:
    y = np.zeros(subs_csi.shape[0])
for i in enumerate(subs_csi.values):
    sk_id = int(i[1][0])
    #line = [sk_id]
    #table_columns = ['sk_id']
    if TRAIN:
        dt = str(i[1][2]).split('.')
    else:
        dt = str(i[1][1]).split('.')
    year = 2002
    month = int(dt[1])
    row = []
    for j in range(12):
        new_line = get_subs_features(year, month, int(dt[1]), int(dt[0]), sk_id)
        #line.extend(new_line[1])
        row.append(new_line[1])
        #table_columns.extend(new_line[0])
        month -= 1
        if month == 0:
            month = 12
            year -= 1
    table.append(row)
    if TRAIN:
        y[i[0]] = i[1][1]

# %%
data = np.array(table)

# %%
data.shape
# Out:
# (4222, 12, 34)

# %%
np.max(data)
# Out:
# 1.0

# %%
columns_avg = ['CELL_AVAILABILITY_2G', 'CELL_AVAILABILITY_3G',
       'CELL_AVAILABILITY_4G', 'CSSR_2G', 'CSSR_3G',
       'ERAB_PS_BLOCKING_RATE_LTE', 'ERAB_PS_BLOCKING_RATE_PLMN_LTE',
       'ERAB_PS_DROP_RATE_LTE', 'HSPDSCH_CODE_UTIL_3G',
       'NODEB_CNBAP_LOAD_HARDWARE', 'PART_CQI_QPSK_LTE', 'PART_MCS_QPSK_LTE',
       'PROC_LOAD_3G', 'PSSR_2G', 'PSSR_3G', 'PSSR_LTE',
       'RAB_CS_BLOCKING_RATE_3G', 'RAB_CS_DROP_RATE_3G',
       'RAB_PS_BLOCKING_RATE_3G', 'RAB_PS_DROP_RATE_3G', 'RBU_AVAIL_DL',
       'RBU_AVAIL_DL_LTE', 'RBU_AVAIL_UL', 'RBU_OTHER_DL', 'RBU_OTHER_UL',
       'RBU_OWN_DL', 'RBU_OWN_UL', 'RRC_BLOCKING_RATE_3G',
       'RRC_BLOCKING_RATE_LTE', 'RTWP_3G', 'SHO_FACTOR', 'TBF_DROP_RATE_2G',
       'TCH_DROP_RATE_2G', 'UTIL_BRD_CPU_3G', 'UTIL_CE_DL_3G',
       'UTIL_CE_HW_DL_3G', 'UTIL_CE_UL_3G', 'UTIL_SUBUNITS_3G',
       'UL_VOLUME_LTE', 'DL_VOLUME_LTE', 'TOTAL_DL_VOLUME_3G',
       'TOTAL_UL_VOLUME_3G']

# %%
columns_chhn = ['AVEUSERNUMBER', 'AVEUSERNUMBER_PLMN',
       'AVR_DL_HSPA_USER_3G', 'AVR_DL_R99_USER_3G', 'AVR_DL_USER_3G',
       'AVR_DL_USER_LTE', 'AVR_TX_POWER_3G', 'AVR_UL_HSPA_USER',
       'AVR_UL_R99_USER', 'AVR_UL_USER_3G', 'AVR_UL_USER_LTE',
       'DL_AVR_THROUGHPUT_3G', 'DL_AVR_THROUGHPUT_LTE',
       'DL_AVR_THROUGHPUT_R99', 'DL_MEAN_USER_THROUGHPUT_LTE',
       'DL_MEAN_USER_THROUGHPUT_DL_2G', 'DL_MEAN_USER_THROUGHPUT_HSPA3G',
       'DL_MEAN_USER_THROUGHPUT_PLTE', 'DL_MEAN_USER_THROUGHPUT_REL93G',
       'HSDPA_USERS_3G', 'HSUPA_USERS_3G', 'RBU_USED_DL', 'RBU_USED_UL',
       'RELATIVE_RBU_USED_DL', 'RELATIVE_RBU_USED_UL', 'RELATIVE_TX_POWER_3G',
       'UL_AVR_THROUGHPUT_3G', 'UL_AVR_THROUGHPUT_LTE',
       'UL_AVR_THROUGHPUT_R99', 'UL_MEAN_USER_THROUGHPUT_LTE',
       'UL_MEAN_USER_THROUGHPUT_HS3G', 'UL_MEAN_USER_THROUGHPUT_PLTE',
       'UL_MEAN_USER_THROUGHPUT_REL93G']

# %%
def get_columns(count, postfix):
    return ['{} {}'.format(i, postfix) for i in range(count)]

# %%
if TRAIN:
    scalers = {}

# %%
def get_extend_data(type_data, column_name, count, postfix):
    fname = pathfiles + path_features + '{}_{}.csv'.format(type_data, column_name)
    result = pd.read_csv(fname)
    table = []
    result = result[get_columns(count, postfix)]
    result.fillna(np.nanmean(result), inplace=True)
    for i in result.values:
        table.append(np.array(i).reshape((count, 1)))
    res_table = np.array(table)
    
    if TRAIN:
        scale_mean = np.min(res_table)
        res_table -= scale_mean
        scale_std = np.max(res_table)
        if scale_std != 0:
            res_table /= scale_std
        scalers[(type_data, column_name, count, postfix)] = (scale_mean, scale_std)
    else:
        scale_mean = scalers[(type_data, column_name, count, postfix)][0]
        scale_std = scalers[(type_data, column_name, count, postfix)][1]
        res_table -= scale_mean
        if scale_std != 0:
            res_table /= scale_std
    return res_table

def get_all_data():
    result = []
    count_days = 60
    for columns in [columns_avg, columns_chhn]:
        for type_data in ['data', 'voice']:
            for c in columns:
                result2 = None
                for a in ['sum', 'count', 'min', 'avg', 'max', 'mina', 'avga', 'maxa']:
                    t = get_extend_data(type_data, c, count_days, a)
                    if result2 is None:
                        result2 = t
                    else:
                        result2 = np.concatenate([result2, t], axis=2)
                result.append(result2)
    return result

# %%
data2 = get_all_data()

# %%
len(data2)
# Out:
# 150

# %%
X = [np.asarray(i.tolist()) for i in data2]

# %%
y = np.asarray(y)

# %%
X[0].shape
# Out:
# (4222, 45, 8)

# %%
X = data2

# %%
from sklearn.model_selection import train_test_split

# %%
#X_train, X_test, y_train, y_test 
a = train_test_split(*X, y, test_size=0.2, random_state=43)

# %%
X_train = []
X_test = []
y_train = a[-2]
y_test = a[-1]
has_train = True
for i in a:
    if len(i.shape) == 1:
        continue
    if has_train:
        X_train.append(i)
    else:
        X_test.append(i)
    has_train = not has_train

# %%
from sklearn.utils.class_weight import compute_class_weight

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Conv1D, MaxPooling1D, Flatten, Input, GlobalMaxPooling1D, GRU, Bidirectional, LSTM
from keras.utils import np_utils
from keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import roc_auc_score
from keras import regularizers, Input, layers

# %%
from sklearn import metrics
from keras import backend as K
import tensorflow as tf
def auc(y_true, y_pred):
    auc = tf.metrics.auc(y_true, y_pred)[1]
    K.get_session().run(tf.local_variables_initializer())
    return auc

# %%
def create_sub_model(input_data):
    input_layer = Input(shape=input_data.shape[1:], dtype='float32')
    #x_0 = GRU(64, dropout=0.3, recurrent_dropout=0.3, activation='relu', kernel_regularizer=regularizers.l2(0.005))(input_layer)
    x_0 = Conv1D(32, 3, activation='relu')(input_layer)
    x_0 = MaxPooling1D(3)(x_0)
    x_0 = Conv1D(32, 3, activation='relu')(x_0)
    x_0 = GlobalMaxPooling1D()(x_0)
    x_0 = Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x_0)
    
    return input_layer, x_0

def create_model():
    #build Keras model
    
    first_layers = []
    inputs = []
    for i in X_train:
        _input, _layer = create_sub_model(i)
        first_layers.append(_layer)
        inputs.append(_input)
    
    concatenated = layers.concatenate(first_layers, axis=-1)
    
    preds = Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.005))(concatenated)
    #preds = Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.005))(preds)
    #preds = Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.005))(preds)
    #preds = Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.005))(preds)
    preds = Dense(1, activation='sigmoid')(concatenated)
        
    model = Model(inputs, preds)
        
    model.compile(loss='binary_crossentropy', metrics=[auc], optimizer='adam')
    return model

# %%
count_epochs = 600
class_weights = compute_class_weight('balanced', np.unique(y_train), y_train)
model = create_model()
early_stopping_monitor = EarlyStopping(patience=10)
history = model.fit([np.array(i) for i in X_train], np.array(y_train), batch_size = 64, epochs = count_epochs, verbose=1, validation_split=0.2, class_weight=class_weights, callbacks=[plot,early_stopping_monitor])
# Out:
# 2701/2701 [==============================] - 416s 154ms/step - loss: 0.3891 - auc: 0.5806 - val_loss: 0.4698 - val_auc: 0.5823

# %%
predict = model.predict([np.array(i) for i in X_test])
score = roc_auc_score(y_test, predict)
text = "Total roc auc score = {0:0.4f}".format(score)
print(text)
# Out:
# Total roc auc score = 0.5455

# %%
send_notify(text)

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_471 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_472 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_473 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_474 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_475 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_476 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_477 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_478 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_479 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_480 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_481 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_482 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_483 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_484 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_485 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_486 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_487 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_488 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_489 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_490 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_491 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_492 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_493 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_494 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_495 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_496 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_497 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_498 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_499 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_500 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_501 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_502 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_503 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_504 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_505 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_506 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_507 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_508 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_509 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_510 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_511 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_512 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_513 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_514 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_515 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_516 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_517 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_518 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_519 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_520 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_521 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_522 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_523 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_524 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_525 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_526 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_527 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_528 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_529 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_530 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_531 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_532 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_533 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_534 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_535 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_536 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_537 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_538 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_539 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_540 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_541 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_542 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_543 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_544 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_545 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_546 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_547 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_548 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_549 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_550 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_551 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_552 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_553 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_554 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_555 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_556 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_557 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_558 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_559 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_560 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_561 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_562 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_563 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_564 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_565 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_566 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_567 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_568 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_569 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_570 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_571 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_572 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_573 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_574 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_575 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_576 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_577 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_578 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_579 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_580 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_581 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_582 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_583 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_584 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_585 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_586 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_587 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_588 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_589 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_590 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_591 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_592 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_593 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_594 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_595 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_596 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_597 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_598 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_599 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_600 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_601 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_602 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_603 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_604 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_605 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_606 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_607 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_608 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_609 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_610 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_611 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_612 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_613 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_614 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_615 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_616 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_617 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_618 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_619 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# input_620 (InputLayer)          (None, 45, 8)        0
# __________________________________________________________________________________________________
# gru_321 (GRU)                   (None, 32)           3936        input_471[0][0]
# __________________________________________________________________________________________________
# gru_322 (GRU)                   (None, 32)           3936        input_472[0][0]
# __________________________________________________________________________________________________
# gru_323 (GRU)                   (None, 32)           3936        input_473[0][0]
# __________________________________________________________________________________________________
# gru_324 (GRU)                   (None, 32)           3936        input_474[0][0]
# __________________________________________________________________________________________________
# gru_325 (GRU)                   (None, 32)           3936        input_475[0][0]
# __________________________________________________________________________________________________
# gru_326 (GRU)                   (None, 32)           3936        input_476[0][0]
# __________________________________________________________________________________________________
# gru_327 (GRU)                   (None, 32)           3936        input_477[0][0]
# __________________________________________________________________________________________________
# gru_328 (GRU)                   (None, 32)           3936        input_478[0][0]
# __________________________________________________________________________________________________
# gru_329 (GRU)                   (None, 32)           3936        input_479[0][0]
# __________________________________________________________________________________________________
# gru_330 (GRU)                   (None, 32)           3936        input_480[0][0]
# __________________________________________________________________________________________________
# gru_331 (GRU)                   (None, 32)           3936        input_481[0][0]
# __________________________________________________________________________________________________
# gru_332 (GRU)                   (None, 32)           3936        input_482[0][0]
# __________________________________________________________________________________________________
# gru_333 (GRU)                   (None, 32)           3936        input_483[0][0]
# __________________________________________________________________________________________________
# gru_334 (GRU)                   (None, 32)           3936        input_484[0][0]
# __________________________________________________________________________________________________
# gru_335 (GRU)                   (None, 32)           3936        input_485[0][0]
# __________________________________________________________________________________________________
# gru_336 (GRU)                   (None, 32)           3936        input_486[0][0]
# __________________________________________________________________________________________________
# gru_337 (GRU)                   (None, 32)           3936        input_487[0][0]
# __________________________________________________________________________________________________
# gru_338 (GRU)                   (None, 32)           3936        input_488[0][0]
# __________________________________________________________________________________________________
# gru_339 (GRU)                   (None, 32)           3936        input_489[0][0]
# __________________________________________________________________________________________________
# gru_340 (GRU)                   (None, 32)           3936        input_490[0][0]
# __________________________________________________________________________________________________
# gru_341 (GRU)                   (None, 32)           3936        input_491[0][0]
# __________________________________________________________________________________________________
# gru_342 (GRU)                   (None, 32)           3936        input_492[0][0]
# __________________________________________________________________________________________________
# gru_343 (GRU)                   (None, 32)           3936        input_493[0][0]
# __________________________________________________________________________________________________
# gru_344 (GRU)                   (None, 32)           3936        input_494[0][0]
# __________________________________________________________________________________________________
# gru_345 (GRU)                   (None, 32)           3936        input_495[0][0]
# __________________________________________________________________________________________________
# gru_346 (GRU)                   (None, 32)           3936        input_496[0][0]
# __________________________________________________________________________________________________
# gru_347 (GRU)                   (None, 32)           3936        input_497[0][0]
# __________________________________________________________________________________________________
# gru_348 (GRU)                   (None, 32)           3936        input_498[0][0]
# __________________________________________________________________________________________________
# gru_349 (GRU)                   (None, 32)           3936        input_499[0][0]
# __________________________________________________________________________________________________
# gru_350 (GRU)                   (None, 32)           3936        input_500[0][0]
# __________________________________________________________________________________________________
# gru_351 (GRU)                   (None, 32)           3936        input_501[0][0]
# __________________________________________________________________________________________________
# gru_352 (GRU)                   (None, 32)           3936        input_502[0][0]
# __________________________________________________________________________________________________
# gru_353 (GRU)                   (None, 32)           3936        input_503[0][0]
# __________________________________________________________________________________________________
# gru_354 (GRU)                   (None, 32)           3936        input_504[0][0]
# __________________________________________________________________________________________________
# gru_355 (GRU)                   (None, 32)           3936        input_505[0][0]
# __________________________________________________________________________________________________
# gru_356 (GRU)                   (None, 32)           3936        input_506[0][0]
# __________________________________________________________________________________________________
# gru_357 (GRU)                   (None, 32)           3936        input_507[0][0]
# __________________________________________________________________________________________________
# gru_358 (GRU)                   (None, 32)           3936        input_508[0][0]
# __________________________________________________________________________________________________
# gru_359 (GRU)                   (None, 32)           3936        input_509[0][0]
# __________________________________________________________________________________________________
# gru_360 (GRU)                   (None, 32)           3936        input_510[0][0]
# __________________________________________________________________________________________________
# gru_361 (GRU)                   (None, 32)           3936        input_511[0][0]
# __________________________________________________________________________________________________
# gru_362 (GRU)                   (None, 32)           3936        input_512[0][0]
# __________________________________________________________________________________________________
# gru_363 (GRU)                   (None, 32)           3936        input_513[0][0]
# __________________________________________________________________________________________________
# gru_364 (GRU)                   (None, 32)           3936        input_514[0][0]
# __________________________________________________________________________________________________
# gru_365 (GRU)                   (None, 32)           3936        input_515[0][0]
# __________________________________________________________________________________________________
# gru_366 (GRU)                   (None, 32)           3936        input_516[0][0]
# __________________________________________________________________________________________________
# gru_367 (GRU)                   (None, 32)           3936        input_517[0][0]
# __________________________________________________________________________________________________
# gru_368 (GRU)                   (None, 32)           3936        input_518[0][0]
# __________________________________________________________________________________________________
# gru_369 (GRU)                   (None, 32)           3936        input_519[0][0]
# __________________________________________________________________________________________________
# gru_370 (GRU)                   (None, 32)           3936        input_520[0][0]
# __________________________________________________________________________________________________
# gru_371 (GRU)                   (None, 32)           3936        input_521[0][0]
# __________________________________________________________________________________________________
# gru_372 (GRU)                   (None, 32)           3936        input_522[0][0]
# __________________________________________________________________________________________________
# gru_373 (GRU)                   (None, 32)           3936        input_523[0][0]
# __________________________________________________________________________________________________
# gru_374 (GRU)                   (None, 32)           3936        input_524[0][0]
# __________________________________________________________________________________________________
# gru_375 (GRU)                   (None, 32)           3936        input_525[0][0]
# __________________________________________________________________________________________________
# gru_376 (GRU)                   (None, 32)           3936        input_526[0][0]
# __________________________________________________________________________________________________
# gru_377 (GRU)                   (None, 32)           3936        input_527[0][0]
# __________________________________________________________________________________________________
# gru_378 (GRU)                   (None, 32)           3936        input_528[0][0]
# __________________________________________________________________________________________________
# gru_379 (GRU)                   (None, 32)           3936        input_529[0][0]
# __________________________________________________________________________________________________
# gru_380 (GRU)                   (None, 32)           3936        input_530[0][0]
# __________________________________________________________________________________________________
# gru_381 (GRU)                   (None, 32)           3936        input_531[0][0]
# __________________________________________________________________________________________________
# gru_382 (GRU)                   (None, 32)           3936        input_532[0][0]
# __________________________________________________________________________________________________
# gru_383 (GRU)                   (None, 32)           3936        input_533[0][0]
# __________________________________________________________________________________________________
# gru_384 (GRU)                   (None, 32)           3936        input_534[0][0]
# __________________________________________________________________________________________________
# gru_385 (GRU)                   (None, 32)           3936        input_535[0][0]
# __________________________________________________________________________________________________
# gru_386 (GRU)                   (None, 32)           3936        input_536[0][0]
# __________________________________________________________________________________________________
# gru_387 (GRU)                   (None, 32)           3936        input_537[0][0]
# __________________________________________________________________________________________________
# gru_388 (GRU)                   (None, 32)           3936        input_538[0][0]
# __________________________________________________________________________________________________
# gru_389 (GRU)                   (None, 32)           3936        input_539[0][0]
# __________________________________________________________________________________________________
# gru_390 (GRU)                   (None, 32)           3936        input_540[0][0]
# __________________________________________________________________________________________________
# gru_391 (GRU)                   (None, 32)           3936        input_541[0][0]
# __________________________________________________________________________________________________
# gru_392 (GRU)                   (None, 32)           3936        input_542[0][0]
# __________________________________________________________________________________________________
# gru_393 (GRU)                   (None, 32)           3936        input_543[0][0]
# __________________________________________________________________________________________________
# gru_394 (GRU)                   (None, 32)           3936        input_544[0][0]
# __________________________________________________________________________________________________
# gru_395 (GRU)                   (None, 32)           3936        input_545[0][0]
# __________________________________________________________________________________________________
# gru_396 (GRU)                   (None, 32)           3936        input_546[0][0]
# __________________________________________________________________________________________________
# gru_397 (GRU)                   (None, 32)           3936        input_547[0][0]
# __________________________________________________________________________________________________
# gru_398 (GRU)                   (None, 32)           3936        input_548[0][0]
# __________________________________________________________________________________________________
# gru_399 (GRU)                   (None, 32)           3936        input_549[0][0]
# __________________________________________________________________________________________________
# gru_400 (GRU)                   (None, 32)           3936        input_550[0][0]
# __________________________________________________________________________________________________
# gru_401 (GRU)                   (None, 32)           3936        input_551[0][0]
# __________________________________________________________________________________________________
# gru_402 (GRU)                   (None, 32)           3936        input_552[0][0]
# __________________________________________________________________________________________________
# gru_403 (GRU)                   (None, 32)           3936        input_553[0][0]
# __________________________________________________________________________________________________
# gru_404 (GRU)                   (None, 32)           3936        input_554[0][0]
# __________________________________________________________________________________________________
# gru_405 (GRU)                   (None, 32)           3936        input_555[0][0]
# __________________________________________________________________________________________________
# gru_406 (GRU)                   (None, 32)           3936        input_556[0][0]
# __________________________________________________________________________________________________
# gru_407 (GRU)                   (None, 32)           3936        input_557[0][0]
# __________________________________________________________________________________________________
# gru_408 (GRU)                   (None, 32)           3936        input_558[0][0]
# __________________________________________________________________________________________________
# gru_409 (GRU)                   (None, 32)           3936        input_559[0][0]
# __________________________________________________________________________________________________
# gru_410 (GRU)                   (None, 32)           3936        input_560[0][0]
# __________________________________________________________________________________________________
# gru_411 (GRU)                   (None, 32)           3936        input_561[0][0]
# ...
# gru_468 (GRU)                   (None, 32)           3936        input_618[0][0]
# __________________________________________________________________________________________________
# gru_469 (GRU)                   (None, 32)           3936        input_619[0][0]
# __________________________________________________________________________________________________
# gru_470 (GRU)                   (None, 32)           3936        input_620[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 4800)         0           gru_321[0][0]
#                                                                  gru_322[0][0]
#                                                                  gru_323[0][0]
#                                                                  gru_324[0][0]
#                                                                  gru_325[0][0]
#                                                                  gru_326[0][0]
#                                                                  gru_327[0][0]
#                                                                  gru_328[0][0]
#                                                                  gru_329[0][0]
#                                                                  gru_330[0][0]
#                                                                  gru_331[0][0]
#                                                                  gru_332[0][0]
#                                                                  gru_333[0][0]
#                                                                  gru_334[0][0]
#                                                                  gru_335[0][0]
#                                                                  gru_336[0][0]
#                                                                  gru_337[0][0]
#                                                                  gru_338[0][0]
#                                                                  gru_339[0][0]
#                                                                  gru_340[0][0]
#                                                                  gru_341[0][0]
#                                                                  gru_342[0][0]
#                                                                  gru_343[0][0]
#                                                                  gru_344[0][0]
#                                                                  gru_345[0][0]
#                                                                  gru_346[0][0]
#                                                                  gru_347[0][0]
#                                                                  gru_348[0][0]
#                                                                  gru_349[0][0]
#                                                                  gru_350[0][0]
#                                                                  gru_351[0][0]
#                                                                  gru_352[0][0]
#                                                                  gru_353[0][0]
#                                                                  gru_354[0][0]
#                                                                  gru_355[0][0]
#                                                                  gru_356[0][0]
#                                                                  gru_357[0][0]
#                                                                  gru_358[0][0]
#                                                                  gru_359[0][0]
#                                                                  gru_360[0][0]
#                                                                  gru_361[0][0]
#                                                                  gru_362[0][0]
#                                                                  gru_363[0][0]
#                                                                  gru_364[0][0]
#                                                                  gru_365[0][0]
#                                                                  gru_366[0][0]
#                                                                  gru_367[0][0]
#                                                                  gru_368[0][0]
#                                                                  gru_369[0][0]
#                                                                  gru_370[0][0]
#                                                                  gru_371[0][0]
#                                                                  gru_372[0][0]
#                                                                  gru_373[0][0]
#                                                                  gru_374[0][0]
#                                                                  gru_375[0][0]
#                                                                  gru_376[0][0]
#                                                                  gru_377[0][0]
#                                                                  gru_378[0][0]
#                                                                  gru_379[0][0]
#                                                                  gru_380[0][0]
#                                                                  gru_381[0][0]
#                                                                  gru_382[0][0]
#                                                                  gru_383[0][0]
#                                                                  gru_384[0][0]
#                                                                  gru_385[0][0]
#                                                                  gru_386[0][0]
#                                                                  gru_387[0][0]
#                                                                  gru_388[0][0]
#                                                                  gru_389[0][0]
#                                                                  gru_390[0][0]
#                                                                  gru_391[0][0]
#                                                                  gru_392[0][0]
#                                                                  gru_393[0][0]
#                                                                  gru_394[0][0]
#                                                                  gru_395[0][0]
#                                                                  gru_396[0][0]
#                                                                  gru_397[0][0]
#                                                                  gru_398[0][0]
#                                                                  gru_399[0][0]
#                                                                  gru_400[0][0]
#                                                                  gru_401[0][0]
#                                                                  gru_402[0][0]
#                                                                  gru_403[0][0]
#                                                                  gru_404[0][0]
#                                                                  gru_405[0][0]
#                                                                  gru_406[0][0]
#                                                                  gru_407[0][0]
#                                                                  gru_408[0][0]
#                                                                  gru_409[0][0]
#                                                                  gru_410[0][0]
#                                                                  gru_411[0][0]
#                                                                  gru_412[0][0]
#                                                                  gru_413[0][0]
#                                                                  gru_414[0][0]
#                                                                  gru_415[0][0]
#                                                                  gru_416[0][0]
#                                                                  gru_417[0][0]
#                                                                  gru_418[0][0]
#                                                                  gru_419[0][0]
#                                                                  gru_420[0][0]
#                                                                  gru_421[0][0]
#                                                                  gru_422[0][0]
#                                                                  gru_423[0][0]
#                                                                  gru_424[0][0]
#                                                                  gru_425[0][0]
#                                                                  gru_426[0][0]
#                                                                  gru_427[0][0]
#                                                                  gru_428[0][0]
#                                                                  gru_429[0][0]
#                                                                  gru_430[0][0]
#                                                                  gru_431[0][0]
#                                                                  gru_432[0][0]
#                                                                  gru_433[0][0]
#                                                                  gru_434[0][0]
#                                                                  gru_435[0][0]
#                                                                  gru_436[0][0]
#                                                                  gru_437[0][0]
#                                                                  gru_438[0][0]
#                                                                  gru_439[0][0]
#                                                                  gru_440[0][0]
#                                                                  gru_441[0][0]
#                                                                  gru_442[0][0]
#                                                                  gru_443[0][0]
#                                                                  gru_444[0][0]
#                                                                  gru_445[0][0]
#                                                                  gru_446[0][0]
#                                                                  gru_447[0][0]
#                                                                  gru_448[0][0]
#                                                                  gru_449[0][0]
#                                                                  gru_450[0][0]
#                                                                  gru_451[0][0]
#                                                                  gru_452[0][0]
#                                                                  gru_453[0][0]
#                                                                  gru_454[0][0]
#                                                                  gru_455[0][0]
#                                                                  gru_456[0][0]
#                                                                  gru_457[0][0]
#                                                                  gru_458[0][0]
#                                                                  gru_459[0][0]
#                                                                  gru_460[0][0]
#                                                                  gru_461[0][0]
#                                                                  gru_462[0][0]
#                                                                  gru_463[0][0]
#                                                                  gru_464[0][0]
#                                                                  gru_465[0][0]
#                                                                  gru_466[0][0]
#                                                                  gru_467[0][0]
#                                                                  gru_468[0][0]
#                                                                  gru_469[0][0]
#                                                                  gru_470[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 1)            4801        concatenate_5[0][0]
# ==================================================================================================
# Total params: 595,201
# Trainable params: 595,201
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history_gr = history.history['val_loss']
import matplotlib.pyplot as plt
epochs = range(1, len(history_gr) + 1)
plt.plot(epochs, history_gr, 'b+', label='Original model')
plt.xlabel('Epochs')
plt.ylabel('Validation loss')
plt.legend()

plt.show()

# %%
model_json = model.to_json()
# Записываем модель в файл
json_file = open("output/sale_model3.json", "w")
json_file.write(model_json)
json_file.close()
model.save_weights("output/sale_model3.h5")

# %%
def save_predict(predict):
    with open('output/second.csv', 'w') as f:
        for item in predict:
            f.write("%s\n" % item[0])

# %%
save_predict(model.predict([np.array(X1), np.array(X2), np.array(X3), np.array(X4)]))
