# %%
import os.path

# %%
TRAIN = True

# %%
path = 'c:/data/mlbootcamp/dataset/'
path_train = path + 'train/'
path_test = path + 'test/'
pathfeatures = 'features/'
if TRAIN:
    pathfiles = path_train
    path_subs_bs_consumption = 'subs_bs_consumption_train.csv'
    path_subs_bs_data_session = 'subs_bs_data_session_train.csv'
    path_subs_bs_voice_session = 'subs_bs_voice_session_train.csv'
    path_subs_features = 'subs_features_train.csv'
    path_subs_csi = 'subs_csi_train.csv'
else:
    pathfiles = path_test
    path_subs_bs_consumption = 'subs_bs_consumption_test.csv'
    path_subs_bs_data_session = 'subs_bs_data_session_test.csv'
    path_subs_bs_voice_session = 'subs_bs_voice_session_test.csv'
    path_subs_features = 'subs_features_test.csv'
    path_subs_csi = 'subs_csi_test.csv'

# %%
columns_avg = ['CELL_AVAILABILITY_2G', 'CELL_AVAILABILITY_3G',
       'CELL_AVAILABILITY_4G', 'CSSR_2G', 'CSSR_3G',
       'ERAB_PS_BLOCKING_RATE_LTE', 'ERAB_PS_BLOCKING_RATE_PLMN_LTE',
       'ERAB_PS_DROP_RATE_LTE', 'HSPDSCH_CODE_UTIL_3G',
       'NODEB_CNBAP_LOAD_HARDWARE', 'PART_CQI_QPSK_LTE', 'PART_MCS_QPSK_LTE',
       'PROC_LOAD_3G', 'PSSR_2G', 'PSSR_3G', 'PSSR_LTE',
       'RAB_CS_BLOCKING_RATE_3G', 'RAB_CS_DROP_RATE_3G',
       'RAB_PS_BLOCKING_RATE_3G', 'RAB_PS_DROP_RATE_3G', 'RBU_AVAIL_DL',
       'RBU_AVAIL_DL_LTE', 'RBU_AVAIL_UL', 'RBU_OTHER_DL', 'RBU_OTHER_UL',
       'RBU_OWN_DL', 'RBU_OWN_UL', 'RRC_BLOCKING_RATE_3G',
       'RRC_BLOCKING_RATE_LTE', 'RTWP_3G', 'SHO_FACTOR', 'TBF_DROP_RATE_2G',
       'TCH_DROP_RATE_2G', 'UTIL_BRD_CPU_3G', 'UTIL_CE_DL_3G',
       'UTIL_CE_HW_DL_3G', 'UTIL_CE_UL_3G', 'UTIL_SUBUNITS_3G',
       'UL_VOLUME_LTE', 'DL_VOLUME_LTE', 'TOTAL_DL_VOLUME_3G',
       'TOTAL_UL_VOLUME_3G']

# %%
columns_chhn = ['AVEUSERNUMBER', 'AVEUSERNUMBER_PLMN',
       'AVR_DL_HSPA_USER_3G', 'AVR_DL_R99_USER_3G', 'AVR_DL_USER_3G',
       'AVR_DL_USER_LTE', 'AVR_TX_POWER_3G', 'AVR_UL_HSPA_USER',
       'AVR_UL_R99_USER', 'AVR_UL_USER_3G', 'AVR_UL_USER_LTE',
       'DL_AVR_THROUGHPUT_3G', 'DL_AVR_THROUGHPUT_LTE',
       'DL_AVR_THROUGHPUT_R99', 'DL_MEAN_USER_THROUGHPUT_LTE',
       'DL_MEAN_USER_THROUGHPUT_DL_2G', 'DL_MEAN_USER_THROUGHPUT_HSPA3G',
       'DL_MEAN_USER_THROUGHPUT_PLTE', 'DL_MEAN_USER_THROUGHPUT_REL93G',
       'HSDPA_USERS_3G', 'HSUPA_USERS_3G', 'RBU_USED_DL', 'RBU_USED_UL',
       'RELATIVE_RBU_USED_DL', 'RELATIVE_RBU_USED_UL', 'RELATIVE_TX_POWER_3G',
       'UL_AVR_THROUGHPUT_3G', 'UL_AVR_THROUGHPUT_LTE',
       'UL_AVR_THROUGHPUT_R99', 'UL_MEAN_USER_THROUGHPUT_LTE',
       'UL_MEAN_USER_THROUGHPUT_HS3G', 'UL_MEAN_USER_THROUGHPUT_PLTE',
       'UL_MEAN_USER_THROUGHPUT_REL93G']

# %%
all_count = 0
true_count = 0
for columns in [columns_avg, columns_chhn]:
    for c in columns:
        for type_data in ['data', 'voice']:
            fname = pathfiles + pathfeatures + '{}_{}.csv'.format(type_data, c)
            is_exist = os.path.isfile(fname)
            all_count += 1
            true_count += int(is_exist)
            print(is_exist, fname)
print('Complete', true_count, 'of', all_count)
# Out:
# True c:/data/mlbootcamp/dataset/train/features/data_CELL_AVAILABILITY_2G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_CELL_AVAILABILITY_2G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_CELL_AVAILABILITY_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_CELL_AVAILABILITY_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_CELL_AVAILABILITY_4G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_CELL_AVAILABILITY_4G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_CSSR_2G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_CSSR_2G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_CSSR_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_CSSR_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_ERAB_PS_BLOCKING_RATE_LTE.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_ERAB_PS_BLOCKING_RATE_LTE.csv
# True c:/data/mlbootcamp/dataset/train/features/data_ERAB_PS_BLOCKING_RATE_PLMN_LTE.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_ERAB_PS_BLOCKING_RATE_PLMN_LTE.csv
# True c:/data/mlbootcamp/dataset/train/features/data_ERAB_PS_DROP_RATE_LTE.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_ERAB_PS_DROP_RATE_LTE.csv
# True c:/data/mlbootcamp/dataset/train/features/data_HSPDSCH_CODE_UTIL_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_HSPDSCH_CODE_UTIL_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_NODEB_CNBAP_LOAD_HARDWARE.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_NODEB_CNBAP_LOAD_HARDWARE.csv
# True c:/data/mlbootcamp/dataset/train/features/data_PART_CQI_QPSK_LTE.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_PART_CQI_QPSK_LTE.csv
# True c:/data/mlbootcamp/dataset/train/features/data_PART_MCS_QPSK_LTE.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_PART_MCS_QPSK_LTE.csv
# True c:/data/mlbootcamp/dataset/train/features/data_PROC_LOAD_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_PROC_LOAD_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_PSSR_2G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_PSSR_2G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_PSSR_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_PSSR_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_PSSR_LTE.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_PSSR_LTE.csv
# True c:/data/mlbootcamp/dataset/train/features/data_RAB_CS_BLOCKING_RATE_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_RAB_CS_BLOCKING_RATE_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_RAB_CS_DROP_RATE_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_RAB_CS_DROP_RATE_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_RAB_PS_BLOCKING_RATE_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_RAB_PS_BLOCKING_RATE_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_RAB_PS_DROP_RATE_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_RAB_PS_DROP_RATE_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_RBU_AVAIL_DL.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_RBU_AVAIL_DL.csv
# True c:/data/mlbootcamp/dataset/train/features/data_RBU_AVAIL_DL_LTE.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_RBU_AVAIL_DL_LTE.csv
# True c:/data/mlbootcamp/dataset/train/features/data_RBU_AVAIL_UL.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_RBU_AVAIL_UL.csv
# True c:/data/mlbootcamp/dataset/train/features/data_RBU_OTHER_DL.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_RBU_OTHER_DL.csv
# True c:/data/mlbootcamp/dataset/train/features/data_RBU_OTHER_UL.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_RBU_OTHER_UL.csv
# True c:/data/mlbootcamp/dataset/train/features/data_RBU_OWN_DL.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_RBU_OWN_DL.csv
# True c:/data/mlbootcamp/dataset/train/features/data_RBU_OWN_UL.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_RBU_OWN_UL.csv
# True c:/data/mlbootcamp/dataset/train/features/data_RRC_BLOCKING_RATE_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_RRC_BLOCKING_RATE_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_RRC_BLOCKING_RATE_LTE.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_RRC_BLOCKING_RATE_LTE.csv
# True c:/data/mlbootcamp/dataset/train/features/data_RTWP_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_RTWP_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_SHO_FACTOR.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_SHO_FACTOR.csv
# True c:/data/mlbootcamp/dataset/train/features/data_TBF_DROP_RATE_2G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_TBF_DROP_RATE_2G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_TCH_DROP_RATE_2G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_TCH_DROP_RATE_2G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_UTIL_BRD_CPU_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_UTIL_BRD_CPU_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_UTIL_CE_DL_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_UTIL_CE_DL_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_UTIL_CE_HW_DL_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_UTIL_CE_HW_DL_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_UTIL_CE_UL_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_UTIL_CE_UL_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_UTIL_SUBUNITS_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_UTIL_SUBUNITS_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_UL_VOLUME_LTE.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_UL_VOLUME_LTE.csv
# True c:/data/mlbootcamp/dataset/train/features/data_DL_VOLUME_LTE.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_DL_VOLUME_LTE.csv
# True c:/data/mlbootcamp/dataset/train/features/data_TOTAL_DL_VOLUME_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_TOTAL_DL_VOLUME_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_TOTAL_UL_VOLUME_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_TOTAL_UL_VOLUME_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_AVEUSERNUMBER.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_AVEUSERNUMBER.csv
# True c:/data/mlbootcamp/dataset/train/features/data_AVEUSERNUMBER_PLMN.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_AVEUSERNUMBER_PLMN.csv
# True c:/data/mlbootcamp/dataset/train/features/data_AVR_DL_HSPA_USER_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_AVR_DL_HSPA_USER_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_AVR_DL_R99_USER_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_AVR_DL_R99_USER_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_AVR_DL_USER_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_AVR_DL_USER_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_AVR_DL_USER_LTE.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_AVR_DL_USER_LTE.csv
# True c:/data/mlbootcamp/dataset/train/features/data_AVR_TX_POWER_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_AVR_TX_POWER_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_AVR_UL_HSPA_USER.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_AVR_UL_HSPA_USER.csv
# True c:/data/mlbootcamp/dataset/train/features/data_AVR_UL_R99_USER.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_AVR_UL_R99_USER.csv
# True c:/data/mlbootcamp/dataset/train/features/data_AVR_UL_USER_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_AVR_UL_USER_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_AVR_UL_USER_LTE.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_AVR_UL_USER_LTE.csv
# True c:/data/mlbootcamp/dataset/train/features/data_DL_AVR_THROUGHPUT_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_DL_AVR_THROUGHPUT_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_DL_AVR_THROUGHPUT_LTE.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_DL_AVR_THROUGHPUT_LTE.csv
# True c:/data/mlbootcamp/dataset/train/features/data_DL_AVR_THROUGHPUT_R99.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_DL_AVR_THROUGHPUT_R99.csv
# True c:/data/mlbootcamp/dataset/train/features/data_DL_MEAN_USER_THROUGHPUT_LTE.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_DL_MEAN_USER_THROUGHPUT_LTE.csv
# True c:/data/mlbootcamp/dataset/train/features/data_DL_MEAN_USER_THROUGHPUT_DL_2G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_DL_MEAN_USER_THROUGHPUT_DL_2G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_DL_MEAN_USER_THROUGHPUT_HSPA3G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_DL_MEAN_USER_THROUGHPUT_HSPA3G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_DL_MEAN_USER_THROUGHPUT_PLTE.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_DL_MEAN_USER_THROUGHPUT_PLTE.csv
# True c:/data/mlbootcamp/dataset/train/features/data_DL_MEAN_USER_THROUGHPUT_REL93G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_DL_MEAN_USER_THROUGHPUT_REL93G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_HSDPA_USERS_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_HSDPA_USERS_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_HSUPA_USERS_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_HSUPA_USERS_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_RBU_USED_DL.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_RBU_USED_DL.csv
# True c:/data/mlbootcamp/dataset/train/features/data_RBU_USED_UL.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_RBU_USED_UL.csv
# True c:/data/mlbootcamp/dataset/train/features/data_RELATIVE_RBU_USED_DL.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_RELATIVE_RBU_USED_DL.csv
# True c:/data/mlbootcamp/dataset/train/features/data_RELATIVE_RBU_USED_UL.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_RELATIVE_RBU_USED_UL.csv
# True c:/data/mlbootcamp/dataset/train/features/data_RELATIVE_TX_POWER_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_RELATIVE_TX_POWER_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_UL_AVR_THROUGHPUT_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_UL_AVR_THROUGHPUT_3G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_UL_AVR_THROUGHPUT_LTE.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_UL_AVR_THROUGHPUT_LTE.csv
# True c:/data/mlbootcamp/dataset/train/features/data_UL_AVR_THROUGHPUT_R99.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_UL_AVR_THROUGHPUT_R99.csv
# True c:/data/mlbootcamp/dataset/train/features/data_UL_MEAN_USER_THROUGHPUT_LTE.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_UL_MEAN_USER_THROUGHPUT_LTE.csv
# True c:/data/mlbootcamp/dataset/train/features/data_UL_MEAN_USER_THROUGHPUT_HS3G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_UL_MEAN_USER_THROUGHPUT_HS3G.csv
# True c:/data/mlbootcamp/dataset/train/features/data_UL_MEAN_USER_THROUGHPUT_PLTE.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_UL_MEAN_USER_THROUGHPUT_PLTE.csv
# True c:/data/mlbootcamp/dataset/train/features/data_UL_MEAN_USER_THROUGHPUT_REL93G.csv
# True c:/data/mlbootcamp/dataset/train/features/voice_UL_MEAN_USER_THROUGHPUT_REL93G.csv
# Complete 150 of 150
